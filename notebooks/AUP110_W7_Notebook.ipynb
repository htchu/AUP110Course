# %% [markdown]
# # AU Fundamentals of Python Programming-W5

# %% [markdown]
# ## Topic 1(主題1)-if條件陳述式/if condition statement
# ![761edd878643e26832d88b5f8ca0ad24.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 1: 布林值/boolean
# True / False

# %%
print(True) 
print(False)

# %%
print(5>3) 
print(5<3)

# %%
bmi = 21.0
print(bmi>24.0) #24.0 is too fat

# %%
bmi = 18.0
print(bmi<18.5) #18.5 is too skinny

# %%
bmi = float(input("Input yout bmi"))
print(bmi>24.0)

# %% [markdown]
# ### Step 2: if-condition
# ```
# if 布林一:
#     # 布林一被評估為 True 時候執行縮排的程式碼
# elif 布林二:
#     # 布林二被評估為 True 時候執行縮排的程式碼
# else:
#     # 布林一與布林二都被評估為 False 時候執行縮排的程式碼
# ```

# %%
bmi = float(input("Input yout bmi"))
if bmi>24.0:
  print("Too fat")

# %% [markdown]
# ### Step 3: if-else-condition

# %%
bmi = float(input("Input yout bmi"))
if bmi>24.0:
  print("Too fat")
else:
  print("OK")

# %% [markdown]
# ### Step 4: if-elif-condition

# %%
bmi = float(input("Input yout bmi"))
if bmi>24.0:
  print("Too fat")
elif bmi<18.5:
  print("Too skinny")
else:
  print("OK")

# %% [markdown]
# ## Topic 2(主題2)-運算子/Operator

# %% [markdown]
# ### Step 5: 比較運算子/Comparison Operators: >, >=, < , <=, ==
# | Operators|      Running      |
# |----------|:-------------:|
# | > |  greater than |
# | < |    less than   |
# | >= | greater than or equal |
# | <= | less than or equal |
# | == | equal |
# | != | not equall |

# %%
#判斷奇數偶數
a = 9
if a % 2 == 0:
    print("{} is even".format(a))
else:
    print("{} is odd".format(a))
b = 8
if b % 2 == 0:
    print("{} is even".format(b))
else:
    print("{} is odd".format(b))
# Out:
# 9 is odd
# 8 is even

# %%
#判斷奇數偶數
a = 9
if a % 2 != 1:
    print("{} is even".format(a))
else:
    print("{} is odd".format(a))
b = 8
if b % 2 < 1:
    print("{} is even".format(b))
else:
    print("{} is odd".format(b))
# Out:
# 9 is odd
# 8 is even

# %% [markdown]
# ### Step 6: 布林運算子/Boolean Operators: and, or, not

# %%
bmi = float(input("Input yout bmi"))
if bmi>=18.5 and bmi<24.0:
  print("OK")
else:
  if bmi>24.0:
    print("Too fat")
  else:
    print("Too skinny")

# %%
score1 = int(input("Input yout score1"))
score2 = int(input("Input yout score2"))
if score1 > 60 and score2 > 60:
    print("All pass")
else:
    print("Have failed grades")

# %%
score1 = int(input("Input yout score1"))
score2 = int(input("Input yout score2"))
if score1 < 60 or score2 < 60:
    print("Have failed grades")
else:
    print("All pass")

# %%
score1 = int(input("Input yout score1"))
score2 = int(input("Input yout score2"))
if not(score1 < 60 or score2 < 60):
    print("All pass")
else:
    print("Have failed grades")

# %% [markdown]
# ## Topic 3(主題3)-for-loop-if-condition

# %% [markdown]
# ### Step 7:找出一個數字的所有因數

# %%
num = int(input())
for i in range(1,num+1):
  if num % i ==0:
    print("{} ".format(i), end="")

# %% [markdown]
# ### Step 8:決定一個數字是不是質數(prime number), 除了1和本身之外，沒有別的因數

# %%
num = int(input())
count  = 0
for i in range(2,num):
  if num % i ==0:
    count+=1
    print("{} ".format(i), end="")
print()
if count ==0:
  print("{} is a prime number".format(num))
else:
  print("{} is not a prime number".format(num))

# %% [markdown]
# ### Step 9:break-for-loop

# %%
num = int(input())
count  = 0
for i in range(2,num):
  if num % i ==0:
    count+=1
    break
if count ==0:
  print("{} is a prime number".format(num))
else:
  print("{} is not a prime number".format(num))

# %% [markdown]
# ## Topic 3(主題3)-字串的函數/String functions
# ```
# ```

# %% [markdown]
# ### Step 10: 分割 str.split()

# %%
original_string = "ab_cd_ef"
split_string = original_string.split("_")#splits string by "_"
print(split_string)

# %%
original_string = "ab cd ef"
split_string = original_string.split()#splits string by " "
print(split_string)

# %% [markdown]
# ### Step 11: 大小寫 str.lower(),str.upper()

# %%
ss = "Google was founded in September 1998 by Larry Page and Sergey Brin";
s1 = ss.lower()
s2 = ss.upper()
print(s1)
print(s2)

# %% [markdown]
# ### Step 12: 去頭去尾 str.strip(),str.rstrip(),str.lstrip()

# %%
ss = "   Google was founded in September 1998 by Larry Page and Sergey Brin   ";
s1 = ss.strip() #去頭尾
s2 = ss.rstrip() #去尾
s3 = ss.lstrip() #去頭
print(s1)
print(s2)
print(s3)

# %% [markdown]
# ### Step 13: ascii 轉換 ord(), chr()

# %%
# 輸入字元
ch = input("Keyin a character: ")
print( "The ascii code of character {} is {}".format(ch, ord(ch)))

# %%
# 輸入字元
ch = input("Keyin a character: ")
print( "The ascii code of character {} is {:d}".format(ch, ord(ch))) #:d 10進位數
print( "The ascii code of character {} is 0x{:x}".format(ch, ord(ch))) #:x 16進位數

# %% [markdown]
# ### Step 14: unicode 轉換 ord(), chr()
#
# https://www.ifreesite.com/unicode-ascii-ansi.htm

# %%
s1 = "大家好"
s2 = "\u5927\u5bb6\u597d"
print(s1)
print(s2)

# %%
s1 = "大家好"
s2 = "\u5927\u5bb6\u597d"
print("The unicode code of characters {} is {:d} {:d} {:d}".format(s1, ord(s1[0]), ord(s1[1]), ord(s1[2])))

# %%
s1 = "大家好"
s2 = "\u5927\u5bb6\u597d"
print("The unicode code of characters {} is \\u{:x} \\u{:x} \\u{:x}".format(s1, ord(s1[0]), ord(s1[1]), ord(s1[2])))

# %%
# 輸入字元
ch = input("Keyin a character: ")
print( "The unicode code of character {} is {:d}".format(ch, ord(ch))) #:d 10進位數
print( "The unicode code of character {} is \\u{:x}".format(ch, ord(ch))) #:x 16進位數

# %%
code = 23478
print( "The unicode code of code {} is {}".format(code, chr(code))) # 10進位數

# %%
code = "23478"
code = int(code)
print( "The unicode code of code {} is {}".format(code, chr(code))) # 10進位數

# %%
code = "597d"# 16進位數
code = int(code,16)# 16進位數轉換
print( "The unicode code of code {:x} is {}".format(code, chr(code))) # 16進位數

# %%
# 輸入16進位數的unicode內碼
code = int(input("Keyin a unicode code: "), 16)
print( "The unicode code of code {} is {}".format(code, chr(code))) # 10進位數
